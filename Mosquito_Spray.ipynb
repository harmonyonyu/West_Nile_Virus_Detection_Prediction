# %%
import pandas as pd

spray_df = pd.read_csv('~/Desktop/GA/Week7/project-4/Data/spray.csv')

# %%
spray_df.shape
# Out:
# (14835, 4)

# %%
spray_df.head(25)
# Out:
#           Date        Time   Latitude  Longitude
# 0   2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1   2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2   2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3   2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4   2011-08-29  6:57:38 PM  42.390410 -88.088858
# 5   2011-08-29  6:57:48 PM  42.390395 -88.088315
# 6   2011-08-29  6:57:58 PM  42.390673 -88.088002
# 7   2011-08-29  6:58:08 PM  42.391027 -88.088002
# 8   2011-08-29  6:58:18 PM  42.391403 -88.088003
# 9   2011-08-29  6:58:28 PM  42.391718 -88.087995
# 10  2011-08-29  6:58:38 PM  42.392038 -88.087988
# 11  2011-08-29  6:58:48 PM  42.392410 -88.088078
# 12  2011-08-29  6:58:58 PM  42.392800 -88.088332
# 13  2011-08-29  6:59:08 PM  42.393257 -88.088370
# 14  2011-08-29  6:59:18 PM  42.393600 -88.088232
# 15  2011-08-29  7:00:08 PM  42.393203 -88.088417
# 16  2011-08-29  7:00:18 PM  42.392792 -88.088312
# 17  2011-08-29  7:00:28 PM  42.392477 -88.088210
# ...

# %%
spray_df['date_lat_long'] = list(zip(spray_df.Date, spray_df.Latitude, spray_df.Longitude))

# %%
spray_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 5 columns):
# Date             14835 non-null object
# Time             14251 non-null object
# Latitude         14835 non-null float64
# Longitude        14835 non-null float64
# date_lat_long    14835 non-null object
# dtypes: float64(2), object(3)
# memory usage: 579.6+ KB

# %%
spray_df.shape
# Out:
# (14835, 5)

# %%
spray_df.Date.unique()
# Out:
# array(['2011-08-29', '2011-09-07', '2013-07-17', '2013-07-25',
#        '2013-08-08', '2013-08-15', '2013-08-16', '2013-08-22',
#        '2013-08-29', '2013-09-05'], dtype=object)

# %%
### 10 days total of sprays during 2011 and 2013.

# '2011-08-29', --2011
# '2011-09-07', --2011
# '2013-07-17', 
# '2013-07-25',
# '2013-08-08', 
# '2013-08-15', 
# '2013-08-16', 
# '2013-08-22',
# '2013-08-29', 
# '2013-09-05'

# %%
spray_df
# Out:
#              Date        Time   Latitude  Longitude  \
# 0      2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1      2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2      2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3      2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4      2011-08-29  6:57:38 PM  42.390410 -88.088858
# 5      2011-08-29  6:57:48 PM  42.390395 -88.088315
# 6      2011-08-29  6:57:58 PM  42.390673 -88.088002
# 7      2011-08-29  6:58:08 PM  42.391027 -88.088002
# 8      2011-08-29  6:58:18 PM  42.391403 -88.088003
# 9      2011-08-29  6:58:28 PM  42.391718 -88.087995
# 10     2011-08-29  6:58:38 PM  42.392038 -88.087988
# 11     2011-08-29  6:58:48 PM  42.392410 -88.088078
# 12     2011-08-29  6:58:58 PM  42.392800 -88.088332
# 13     2011-08-29  6:59:08 PM  42.393257 -88.088370
# 14     2011-08-29  6:59:18 PM  42.393600 -88.088232
# 15     2011-08-29  7:00:08 PM  42.393203 -88.088417
# 16     2011-08-29  7:00:18 PM  42.392792 -88.088312
# ...

# %%
spray_df.date_lat_long.groupby(spray_df.Date).value_counts()
# Out:
# Date        date_lat_long
# 2011-08-29  (2011-08-29, 42.38946, -88.09389499999999)             1
#             (2011-08-29, 42.389711666666706, -88.09391)            1
#             (2011-08-29, 42.3897216666667, -88.09383333333331)     1
#             (2011-08-29, 42.389835, -88.0942183333333)             1
#             (2011-08-29, 42.389843333333296, -88.0946666666667)    1
#             (2011-08-29, 42.389855, -88.09508000000001)            1
#             (2011-08-29, 42.3898566666667, -88.09490500000001)     1
#             (2011-08-29, 42.389858333333294, -88.0954866666667)    1
#             (2011-08-29, 42.389866666666705, -88.0958783333333)    1
#             (2011-08-29, 42.38987, -88.0962583333333)              1
#             (2011-08-29, 42.3900483333333, -88.096435)             1
#             (2011-08-29, 42.390066666666705, -88.095155)           1
#             (2011-08-29, 42.390335, -88.0964433333333)             1
# ...
