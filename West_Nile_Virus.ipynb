# %%
import pandas as pd

df = pd.read_csv('~/Desktop/GA/Week7/project-4/Data/train.csv')

# %%
df.shape
# Out:
# (10506, 12)

# %%
df.head(25)
# Out:
#           Date                                            Address  \
# 0   2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1   2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2   2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3   2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4   2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5   2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6   2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7   2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8   2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9   2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 10  2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 11  2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 12  2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...

# %%
df_1 = df.drop(['Address', 'Block','Street','AddressNumberAndStreet','AddressAccuracy'], axis=1)
df_1
# Out:
#              Date                 Species  Trap   Latitude  Longitude  \
# 0      2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 1      2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 2      2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# 3      2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 4      2007-05-29          CULEX RESTUANS  T015  41.974089 -87.824812
# 5      2007-05-29          CULEX RESTUANS  T045  41.921600 -87.666455
# 6      2007-05-29          CULEX RESTUANS  T046  41.891118 -87.654491
# 7      2007-05-29  CULEX PIPIENS/RESTUANS  T048  41.867108 -87.654224
# 8      2007-05-29          CULEX RESTUANS  T048  41.867108 -87.654224
# 9      2007-05-29          CULEX RESTUANS  T049  41.896282 -87.655232
# 10     2007-05-29  CULEX PIPIENS/RESTUANS  T050  41.919343 -87.694259
# 11     2007-05-29  CULEX PIPIENS/RESTUANS  T054  41.921965 -87.632085
# ...

# %%
df_1.Date.groupby(df_1.WnvPresent).value_counts()
# Out:
# WnvPresent  Date
# 0           2007-08-01    533
#             2007-08-15    239
#             2007-10-04    183
#             2011-07-15    177
#             2011-07-25    176
#             2013-07-12    175
#             2007-08-07    172
#             2013-07-19    167
#             2007-09-24    165
#             2009-07-17    164
#             2013-08-01    164
#             2007-08-24    161
#             2007-08-21    154
#             2007-07-11    152
#             2013-07-25    151
#             2013-08-08    147
#             2011-07-11    146
#             2009-07-31    138
#             2013-08-15    137
#             2013-08-22    137
#             2011-08-05    135
#             2007-08-02    134
#             2011-09-12    132
#             2009-08-07    131
#             2007-09-12    130
#             2011-07-29    130
#             2007-07-18    128
#             2009-09-17    127
#             2009-09-25    124
#             2007-09-19    122
# ...

# %%
df_1['date'] = pd.to_datetime(df['Date'])

# %%
wow = df_1.date.groupby(df_1.WnvPresent).value_counts()
wow = pd.DataFrame(wow, index = None)
wow
wow.reset_index(level=['WnvPresent'])
# Out:
#             WnvPresent  date
# date
# 2007-08-01           0   533
# 2007-08-15           0   239
# 2007-10-04           0   183
# 2011-07-15           0   177
# 2011-07-25           0   176
# 2013-07-12           0   175
# 2007-08-07           0   172
# 2013-07-19           0   167
# 2007-09-24           0   165
# 2009-07-17           0   164
# 2013-08-01           0   164
# 2007-08-24           0   161
# 2007-08-21           0   154
# 2007-07-11           0   152
# 2013-07-25           0   151
# 2013-08-08           0   147
# 2011-07-11           0   146
# 2009-07-31           0   138
# 2013-08-15           0   137
# 2013-08-22           0   137
# 2011-08-05           0   135
# 2007-08-02           0   134
# 2011-09-12           0   132
# 2009-08-07           0   131
# 2007-09-12           0   130
# 2011-07-29           0   130
# 2007-07-18           0   128
# 2009-09-17           0   127
# 2009-09-25           0   124
# 2007-09-19           0   122
# ...                ...   ...
# ...

# %%
wow = wow.rename({'WnvPresent':'WnvPresent', 'date':'count'}, axis='columns')
wow
# Out:
#                        count
# WnvPresent date
# 0          2007-08-01    533
#            2007-08-15    239
#            2007-10-04    183
#            2011-07-15    177
#            2011-07-25    176
#            2013-07-12    175
#            2007-08-07    172
#            2013-07-19    167
#            2007-09-24    165
#            2009-07-17    164
#            2013-08-01    164
#            2007-08-24    161
#            2007-08-21    154
#            2007-07-11    152
#            2013-07-25    151
#            2013-08-08    147
#            2011-07-11    146
#            2009-07-31    138
#            2013-08-15    137
#            2013-08-22    137
#            2011-08-05    135
#            2007-08-02    134
#            2011-09-12    132
#            2009-08-07    131
#            2007-09-12    130
#            2011-07-29    130
#            2007-07-18    128
#            2009-09-17    127
#            2009-09-25    124
#            2007-09-19    122
# ...

# %%
virus_present = wow.loc[1]
virus_present
# Out:
#             count
# date
# 2013-08-29     38
# 2007-08-15     37
# 2013-08-08     34
# 2007-08-22     33
# 2007-08-21     32
# 2013-09-06     32
# 2013-08-22     30
# 2007-08-24     25
# 2013-09-12     23
# 2013-08-01     22
# 2013-08-15     20
# 2007-08-01     18
# 2007-08-16     16
# 2013-07-19     15
# 2007-08-07     12
# 2011-08-12     11
# 2013-09-19     11
# 2007-09-05     10
# 2007-08-28      9
# 2007-09-04      8
# 2011-07-29      8
# 2007-08-08      7
# 2007-08-17      7
# 2009-08-25      7
# 2013-07-12      7
# 2011-09-12      6
# 2011-09-23      6
# 2007-07-25      5
# 2007-09-12      5
# 2011-08-05      5
# 2011-08-19      4
# 2011-08-26      4
# 2011-09-01      4
# 2013-09-26      4
# 2007-08-02      3
# 2009-09-14      3
# 2011-07-25      3
# 2011-09-02      3
# 2011-09-16      3
# 2007-09-06      2
# 2007-09-24      2
# 2007-10-04      2
# 2009-07-24      2
# 2009-07-27      2
# 2009-08-13      2
# 2013-07-25      2
# 2007-07-18      1
# 2007-08-09      1
# ...

# %%
virus_present = virus_present.reset_index(level=['date'])

# %%
virus_present.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 2 columns):
# date     53 non-null datetime64[ns]
# count    53 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 928.0 bytes

# %% [markdown]
# ## 53 DAYS OF WEST NILE VIRUS PRESENCE:

# %%
## 53 DATES OF WEST NILE VIRUS PRESENCE:  

virus_present.sort_values(['date'],ascending=False)
# Out:
#          date  count
# 33 2013-09-26      4
# 16 2013-09-19     11
# 8  2013-09-12     23
# 5  2013-09-06     32
# 0  2013-08-29     38
# 6  2013-08-22     30
# 10 2013-08-15     20
# 2  2013-08-08     34
# 9  2013-08-01     22
# 45 2013-07-25      2
# 13 2013-07-19     15
# 24 2013-07-12      7
# 52 2013-06-28      1
# 26 2011-09-23      6
# 38 2011-09-16      3
# 25 2011-09-12      6
# 37 2011-09-02      3
# 32 2011-09-01      4
# 31 2011-08-26      4
# 30 2011-08-19      4
# 15 2011-08-12     11
# 29 2011-08-05      5
# 20 2011-07-29      8
# 36 2011-07-25      3
# 51 2009-09-25      1
# 35 2009-09-14      3
# 50 2009-09-03      1
# 23 2009-08-25      7
# 44 2009-08-13      2
# 49 2009-07-31      1
# 43 2009-07-27      2
# 42 2009-07-24      2
# 41 2007-10-04      2
# 40 2007-09-24      2
# 48 2007-09-19      1
# 28 2007-09-12      5
# 39 2007-09-06      2
# 17 2007-09-05     10
# 19 2007-09-04      8
# 18 2007-08-28      9
# 7  2007-08-24     25
# 3  2007-08-22     33
# ...

# %%
df.Species.groupby(df.WnvPresent).value_counts()
# Out:
# WnvPresent  Species
# 0           CULEX PIPIENS/RESTUANS    4490
#             CULEX RESTUANS            2691
#             CULEX PIPIENS             2459
#             CULEX TERRITANS            222
#             CULEX SALINARIUS            86
#             CULEX TARSALIS               6
#             CULEX ERRATICUS              1
# 1           CULEX PIPIENS/RESTUANS     262
#             CULEX PIPIENS              240
#             CULEX RESTUANS              49
# Name: Species, dtype: int64

# %% [markdown]
# # Test Data Set:

# %%
df_test =  pd.read_csv('~/Desktop/GA/Week7/project-4/Data/test.csv')
df_test
# Out:
#             Id        Date                                            Address  \
# 0            1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1            2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2            3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3            4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4            5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 5            6  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 6            7  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 7            8  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 8            9  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 9           10  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 10          11  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# ...

# %%
df_test.Species.value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    15359
# CULEX RESTUANS            14670
# CULEX PIPIENS             14521
# CULEX SALINARIUS          14355
# CULEX TERRITANS           14351
# CULEX TARSALIS            14347
# UNSPECIFIED CULEX         14345
# CULEX ERRATICUS           14345
# Name: Species, dtype: int64
